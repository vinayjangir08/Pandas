# %%
import pandas as pd

# %%
df = pd.read_csv("D:\ML\DS_data_for_Analysis[002] (1).csv")

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df1 = pd.read_csv("D:\ML\movies_data.csv")
df1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df1.sort_index(axis=1)
# Out:
#                                            actors_list content_rating  \
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              R
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...          PG-13
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              R
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...             PG
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...             PG
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...          PG-13
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...             PG
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              R
#
#      duration      genre  star_rating  \
# 0         142      Crime          9.3
# 1         175      Crime          9.2
# ...

# %%
df1.sort_index(ascending=False)
# Out:
#      star_rating                                            title  \
# 978          7.4                                      Wall Street
# 977          7.4                                      Poltergeist
# 976          7.4  Master and Commander: The Far Side of the World
# 975          7.4                      Back to the Future Part III
# 974          7.4                                          Tootsie
# ..           ...                                              ...
# 4            8.9                                     Pulp Fiction
# 3            9.0                                  The Dark Knight
# 2            9.1                           The Godfather: Part II
# 1            9.2                                    The Godfather
# 0            9.3                         The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 978              R      Crime       126
# 977             PG     Horror       114
# 976          PG-13     Action       138
# ...

# %%
df1.sort_index(ascending=True)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df1.sort_values(['genre'],ascending=False)
# Out:
#      star_rating                               title content_rating    genre  \
# 107          8.3              For a Few Dollars More       APPROVED  Western
# 421          7.9              The Outlaw Josey Wales             PG  Western
# 704          7.6                 High Plains Drifter              R  Western
# 6            8.9      The Good, the Bad and the Ugly      NOT RATED  Western
# 26           8.6        Once Upon a Time in the West          PG-13  Western
# ..           ...                                 ...            ...      ...
# 118          8.3  Indiana Jones and the Last Crusade          PG-13   Action
# 586          7.7     Star Trek II: The Wrath of Khan             PG   Action
# 581          7.8                         Man on Fire              R   Action
# 113          8.3                       Batman Begins          PG-13   Action
# 420          7.9           The Man Who Would Be King             PG   Action
#
# ...

# %%
df1.sort_values(['star_rating'],ascending=True)
# Out:
#      star_rating                           title content_rating    genre  \
# 978          7.4                     Wall Street              R    Crime
# 950          7.4                           Bound              R    Crime
# 949          7.4                      Home Alone             PG   Comedy
# 948          7.4                      Frances Ha              R   Comedy
# 947          7.4                      Eraserhead        UNRATED    Drama
# ..           ...                             ...            ...      ...
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 3            9.0                 The Dark Knight          PG-13   Action
# 2            9.1          The Godfather: Part II              R    Crime
# 1            9.2                   The Godfather              R    Crime
# 0            9.3        The Shawshank Redemption              R    Crime
#
#      duration                                        actors_list
# ...

# %%
df1.sort_values(['duration'])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
df = pd.read_csv('D:\ML\movies_data.csv',index_col='genre')
df
# Out:
#            star_rating                                            title  \
# genre
# Crime              9.3                         The Shawshank Redemption
# Crime              9.2                                    The Godfather
# Crime              9.1                           The Godfather: Part II
# Action             9.0                                  The Dark Knight
# Crime              8.9                                     Pulp Fiction
# ...                ...                                              ...
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
# Crime              7.4                                      Wall Street
#
#           content_rating  duration  \
# genre
# Crime                  R       142
# ...

# %%
df1.set_index('duration',inplace=False)
# Out:
#           star_rating                                            title  \
# duration
# 142               9.3                         The Shawshank Redemption
# 175               9.2                                    The Godfather
# 200               9.1                           The Godfather: Part II
# 152               9.0                                  The Dark Knight
# 154               8.9                                     Pulp Fiction
# ...               ...                                              ...
# 116               7.4                                          Tootsie
# 118               7.4                      Back to the Future Part III
# 138               7.4  Master and Commander: The Far Side of the World
# 114               7.4                                      Poltergeist
# 126               7.4                                      Wall Street
#
#          content_rating      genre  \
# duration
# 142                   R      Crime
# ...

# %%
df1.sort_index()
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.iloc[140]
# Out:
# star_rating                                                     8.3
# title                                             The Wages of Fear
# content_rating                                            NOT RATED
# duration                                                        131
# actors_list       [u'Yves Montand', u'Charles Vanel', u'Peter va...
# Name: Adventure, dtype: object

# %%
df1.iloc[140:200]
# Out:
#      star_rating                                title content_rating  \
# 140          8.3                    The Wages of Fear      NOT RATED
# 141          8.3             The Secret in Their Eyes              R
# 142          8.3    Lagaan: Once Upon a Time in India             PG
# 143          8.2              The Wolf of Wall Street              R
# 144          8.2                It Happened One Night        UNRATED
# 145          8.2                         Blade Runner              R
# 146          8.2                              Warrior          PG-13
# 147          8.2                 Howl's Moving Castle             PG
# 148          8.2                     The Elephant Man             PG
# 149          8.2                              Rebecca      NOT RATED
# 150          8.2                            Incendies              R
# 151          8.2  Lock, Stock and Two Smoking Barrels              R
# 152          8.2                       V for Vendetta              R
# ...

# %% [markdown]
# # Reset index

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      level_0  index content_rating  duration
# 0          0      0              R       142
# 1          1      1              R       175
# 2          2      2              R       200
# 3          3      3          PG-13       152
# 4          4      4              R       154
# ..       ...    ...            ...       ...
# 974      974    974             PG       116
# 975      975    975             PG       118
# 976      976    976          PG-13       138
# 977      977    977             PG       114
# 978      978    978              R       126
#
# [979 rows x 4 columns]

# %% [markdown]
# # Drop NaN,particular Col,Multiple col

# %%
df1.drop('star_rating',axis=1,inplace=True)
df1
# Out:
#     content_rating  duration
# 0                R       142
# 1                R       175
# 2                R       200
# 3            PG-13       152
# 4                R       154
# ..             ...       ...
# 974             PG       116
# 975             PG       118
# 976          PG-13       138
# 977             PG       114
# 978              R       126
#
# [979 rows x 2 columns]

# %%
df1.drop(columns=['title','genre','actors_list'],axis=1,inplace=True)
df1
# Out:
#      star_rating content_rating  duration
# 0            9.3              R       142
# 1            9.2              R       175
# 2            9.1              R       200
# 3            9.0          PG-13       152
# 4            8.9              R       154
# ..           ...            ...       ...
# 974          7.4             PG       116
# 975          7.4             PG       118
# 976          7.4          PG-13       138
# 977          7.4             PG       114
# 978          7.4              R       126
#
# [979 rows x 3 columns]

# %%
df3 = pd.read_excel('"C:\Users\jangi\Downloads\demo.xlsx"')
# Out:
#   Input In [7]
#     df3 = pd.read_excel('"C:\Users\jangi\Downloads\demo.xlsx"')
#                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# %%
df3 = pd.read_csv('test.csv')

# %%
df3
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 1       pqr   97.0   161616.0  mumbai
# 2       abc   26.0  1641964.0    pune
# 3      sfsf    NaN     1166.0     NaN
# 4       NaN  345.0     4646.0    pune
# 5       NaN    NaN        NaN   sfsdf
# 6       NaN    NaN        NaN     NaN
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 9   rewrter   45.0    45456.0    pune
# 10  rewrter   45.0    45456.0    pune
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
df3.dropna()
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 1       pqr   97.0   161616.0  mumbai
# 2       abc   26.0  1641964.0    pune
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 9   rewrter   45.0    45456.0    pune
# 10  rewrter   45.0    45456.0    pune
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
df3.dropna(how='all') # if all values of a row is null then it will remove that particular row
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 1       pqr   97.0   161616.0  mumbai
# 2       abc   26.0  1641964.0    pune
# 3      sfsf    NaN     1166.0     NaN
# 4       NaN  345.0     4646.0    pune
# 5       NaN    NaN        NaN   sfsdf
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 9   rewrter   45.0    45456.0    pune
# 10  rewrter   45.0    45456.0    pune
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
df3.dropna(thresh=2) # @ least 2 value should be not null values in a row
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 1       pqr   97.0   161616.0  mumbai
# 2       abc   26.0  1641964.0    pune
# 3      sfsf    NaN     1166.0     NaN
# 4       NaN  345.0     4646.0    pune
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 9   rewrter   45.0    45456.0    pune
# 10  rewrter   45.0    45456.0    pune
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
df3.dropna(thresh=3) #@ least three values should be not null values
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 1       pqr   97.0   161616.0  mumbai
# 2       abc   26.0  1641964.0    pune
# 4       NaN  345.0     4646.0    pune
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 9   rewrter   45.0    45456.0    pune
# 10  rewrter   45.0    45456.0    pune
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
df3.drop([4,9,10,1,2])
# Out:
#        name    age        sal    city
# 0       xyz   26.0     7555.0   sdfsd
# 3      sfsf    NaN     1166.0     NaN
# 5       NaN    NaN        NaN   sfsdf
# 6       NaN    NaN        NaN     NaN
# 7    fsdafs  534.0     6464.0    pune
# 8    sdfsdf   23.0   464466.0  mumbai
# 11  rewrter   45.0    45456.0    pune
# 12      abc   26.0  1641964.0    pune
# 13      xyz   26.0     7555.0   sdfsd

# %%
ch1=df3.set_index('city')

# %%
ch1.drop('mumbai')
# Out:
#           name    age        sal
# city
# sdfsd      xyz   26.0     7555.0
# pune       abc   26.0  1641964.0
# NaN       sfsf    NaN     1166.0
# pune       NaN  345.0     4646.0
# sfsdf      NaN    NaN        NaN
# NaN        NaN    NaN        NaN
# pune    fsdafs  534.0     6464.0
# pune   rewrter   45.0    45456.0
# pune   rewrter   45.0    45456.0
# pune   rewrter   45.0    45456.0
# pune       abc   26.0  1641964.0
# sdfsd      xyz   26.0     7555.0

# %% [markdown]
# # loc,iloc

# %%
py_dict = {
    'name':['a','b','c','d','e'],
    'city':['pune','mumbai','nagpur','nasik','kolhapur'],
    'pincode':[411043,411001,411033,400012,400123],
    'id':[101,102,103,104,105]}

# %%
py_dict
# Out:
# {'name': ['a', 'b', 'c', 'd', 'e'],
#  'city': ['pune', 'mumbai', 'nagpur', 'nasik', 'kolhapur'],
#  'pincode': [411043, 411001, 411033, 400012, 400123],
#  'id': [101, 102, 103, 104, 105]}

# %%
df5 = pd.DataFrame(py_dict)

# %%
df5
# Out:
#   name      city  pincode   id
# 0    a      pune   411043  101
# 1    b    mumbai   411001  102
# 2    c    nagpur   411033  103
# 3    d     nasik   400012  104
# 4    e  kolhapur   400123  105

# %% [markdown]
# # loc ---actual col_name use here
# # iloc --integer loc

# %%
df5.loc[:,['name','id']]
# Out:
#   name   id
# 0    a  101
# 1    b  102
# 2    c  103
# 3    d  104
# 4    e  105

# %%
df5.loc[[3,4],['name','id']]
# Out:
#   name   id
# 3    d  104
# 4    e  105

# %%
df5.loc[[0,1],['city','pincode']]
# Out:
#      city  pincode
# 0    pune   411043
# 1  mumbai   411001

# %%
df5.loc[:,'name':'pincode']
# Out:
#   name      city  pincode
# 0    a      pune   411043
# 1    b    mumbai   411001
# 2    c    nagpur   411033
# 3    d     nasik   400012
# 4    e  kolhapur   400123

# %%
df5.loc[[0,1,2],'name'::2]
# Out:
#   name  pincode
# 0    a   411043
# 1    b   411001
# 2    c   411033

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df5.loc[[i for i in df5.index if i%2==0]]
# Out:
#   name      city  pincode   id
# 0    a      pune   411043  101
# 2    c    nagpur   411033  103
# 4    e  kolhapur   400123  105

# %%
df5[df5['id']>103]
# Out:
#   name      city  pincode   id
# 3    d     nasik   400012  104
# 4    e  kolhapur   400123  105

# %% [markdown]
# # iloc

# %%
df5.iloc[:,1:3]
# Out:
#        city  pincode
# 0      pune   411043
# 1    mumbai   411001
# 2    nagpur   411033
# 3     nasik   400012
# 4  kolhapur   400123

# %%
# Note :- loc vs iloc differ is that in iloc column call by interger value (0,1,2) like dispite by call as column_name
# in iloc stop index is exclusive ** interview question
