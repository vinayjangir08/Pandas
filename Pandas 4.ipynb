# %%
import pandas as pd

# %%
df= pd.read_csv('D:\ML\movies_data.csv')

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df1=df.groupby('genre')

# %%
df1

# %%
df1.get_group('Crime')
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 67      1
# 195     1
# 76      1
# 66      1
# 205     1
# Name: duration, Length: 133, dtype: int64

# %%
df.groupby('content_rating').get_group('PG')
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 30           8.6                                   Spirited Away
# 32           8.6                                      Casablanca
# 37           8.6                         Raiders of the Lost Ark
# ..           ...                                             ...
# 956          7.4                        Manhattan Murder Mystery
# 962          7.4                              Driving Miss Daisy
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
#
#     content_rating      genre  duration  \
# 12              PG     Action       124
# 19              PG     Action       121
# 30              PG  Animation       125
# ...

# %%
df.groupby(['content_rating','genre']).get_group(('PG','Action'))
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 37           8.6                         Raiders of the Lost Ark
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 327          8.0                    The Adventures of Robin Hood
# 420          7.9                       The Man Who Would Be King
# 586          7.7                 Star Trek II: The Wrath of Khan
# 748          7.6                        The Hunt for Red October
# 753          7.6                            Escape from Alcatraz
# 764          7.6            Indiana Jones and the Temple of Doom
# 908          7.5                                         Bullitt
#
#     content_rating   genre  duration  \
# 12              PG  Action       124
# 19              PG  Action       121
# 37              PG  Action       115
# ...

# %%
df[(df['content_rating']=='R')|(df['content_rating']=='PG')]
# Out:
#      star_rating                        title content_rating      genre  \
# 0            9.3     The Shawshank Redemption              R      Crime
# 1            9.2                The Godfather              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 4            8.9                 Pulp Fiction              R      Crime
# 8            8.9             Schindler's List              R  Biography
# ..           ...                          ...            ...        ...
# 971          7.4           Death at a Funeral              R     Comedy
# 974          7.4                      Tootsie             PG     Comedy
# 975          7.4  Back to the Future Part III             PG  Adventure
# 977          7.4                  Poltergeist             PG     Horror
# 978          7.4                  Wall Street              R      Crime
#
#      duration                                        actors_list
# ...

# %%
df[(df['content_rating']=='R')&(df['genre']=='Biography')]
# Out:
#      star_rating                                              title  \
# 8            8.9                                   Schindler's List
# 18           8.7                                         Goodfellas
# 31           8.6                                   The Intouchables
# 42           8.5                                        The Pianist
# 99           8.4                                            Amadeus
# 124          8.3                                        Raging Bull
# 125          8.3                                           Downfall
# 143          8.2                            The Wolf of Wall Street
# 156          8.2                                             Casino
# 197          8.1                          In the Name of the Father
# 201          8.1                                   12 Years a Slave
# 273          8.1                                           Papillon
# 274          8.1                                  The King's Speech
# ...

# %%
df = pd.read_csv("city_temperature.csv")
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\2053557024.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("city_temperature.csv")

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
df['AvgTemperature'].max()
# Out:
# 110.0

# %%
df[df['AvgTemperature']==df['AvgTemperature'].max()]['Country']
# Out:
# 1034962    Kuwait
# Name: Country, dtype: object

# %%
df[df['AvgTemperature']==df['AvgTemperature'].max()]
# Out:
#               Region Country State    City  Month  Day  Year  AvgTemperature
# 1034962  Middle East  Kuwait   NaN  Kuwait      8    1  2012           110.0

# %%
# display max and min temperture @ same time

# %%
df[(df['AvgTemperature']==df['AvgTemperature'].max()) | (df['AvgTemperature']==df['AvgTemperature'].min())]['AvgTemperature'].value_counts()
# Out:
# -99.0     79672
#  110.0        1
# Name: AvgTemperature, dtype: int64

# %%
# min temperature @ which year

# %%
df[df['AvgTemperature'] == df['AvgTemperature'].max()]['Year']
# Out:
# 1034962    2012
# Name: Year, dtype: int64

# %%
# max temp in 1995

# %%
df.groupby('Year').get_group(1995).max()
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\949555304.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Year').get_group(1995).max()
# Region            South/Central America & Carribean
# Country                                      Zambia
# City                                         Zurich
# Month                                            12
# Day                                              31
# Year                                           1995
# AvgTemperature                                107.3
# dtype: object

# %%
df[df['Region']=='Africa']
# Out:
#         Region  Country State     City  Month  Day  Year  AvgTemperature
# 0       Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1       Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2       Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3       Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4       Africa  Algeria   NaN  Algiers      1    5  1995            47.9
# ...        ...      ...   ...      ...    ...  ...   ...             ...
# 251113  Africa   Zambia   NaN   Lusaka      1   18  2014            71.3
# 251114  Africa   Zambia   NaN   Lusaka      1   19  2014            77.5
# 251115  Africa   Zambia   NaN   Lusaka      1   20  2014            73.4
# 251116  Africa   Zambia   NaN   Lusaka      1   21  2014            73.1
# 251117  Africa   Zambia   NaN   Lusaka      1   22  2014            71.3
#
# [251118 rows x 8 columns]

# %%
df.groupby('Day').get_group(19).max()
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\3170221634.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Day').get_group(19).max()
# Region            South/Central America & Carribean
# Country                                      Zambia
# City                                         Zurich
# Month                                            12
# Day                                              19
# Year                                           2020
# AvgTemperature                                108.8
# dtype: object

# %%
type(df.groupby('Day').get_group(19).max())
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\1195803412.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   type(df.groupby('Day').get_group(19).max())
# pandas.core.series.Series

# %%
pd.DataFrame(df.groupby('Day').get_group(19).max(),columns=['new123'])
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\1496532356.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(df.groupby('Day').get_group(19).max(),columns=['new123'])
#                                            new123
# Region          South/Central America & Carribean
# Country                                    Zambia
# City                                       Zurich
# Month                                          12
# Day                                            19
# Year                                         2020
# AvgTemperature                              108.8

# %%
# max star_rating & its count @ same point of level

# %%
df.groupby('genre').agg(['max','count'])
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\1256445960.py:1: FutureWarning: ['content_rating'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('genre').agg(['max','count'])
#           star_rating                                      title        \
#                   max count                                  max count
# genre
# Action            9.0   136                              Yojimbo   136
# Adventure         8.9    75                            True Grit    75
# Animation         8.6    62                       Wreck-It Ralph    62
# Biography         8.9    77                        Walk the Line    77
# Comedy            8.6   156                           Zombieland   156
# Crime             9.3   124                               Zodiac   124
# Drama             8.9   278                                 Zulu   278
# ...

# %%
df.groupby('star_rating').agg(['max','count'])
# Out:
# C:\Users\jangi\AppData\Local\Temp\ipykernel_14472\1313719744.py:1: FutureWarning: ['content_rating'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('star_rating').agg(['max','count'])
#                                                      title           genre  \
#                                                        max count       max
# star_rating
# 7.4                                       Zero Dark Thirty    49   Mystery
# 7.5                                                  [Rec]   108  Thriller
# 7.6                                When Harry Met Sally...   124   Western
# 7.7                                             Zombieland   113    Sci-Fi
# 7.8                                                   Zulu   116  Thriller
# 7.9                                             Ying xiong    75   Western
# ...

# %%
df[df['star_rating']==df['star_rating'].min()]['genre'].value_counts()
# Out:
# Comedy       15
# Drama        12
# Adventure     7
# Crime         4
# Action        4
# Biography     3
# Animation     2
# Mystery       1
# Horror        1
# Name: genre, dtype: int64

# %%
df['actors_list'].to_list()
# Out:
# ["[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']",
#  "[u'Marlon Brando', u'Al Pacino', u'James Caan']",
#  "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']",
#  "[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']",
#  "[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']",
#  "[u'Henry Fonda', u'Lee J. Cobb', u'Martin Balsam']",
#  "[u'Clint Eastwood', u'Eli Wallach', u'Lee Van Cleef']",
#  "[u'Elijah Wood', u'Viggo Mortensen', u'Ian McKellen']",
#  "[u'Liam Neeson', u'Ralph Fiennes', u'Ben Kingsley']",
#  "[u'Brad Pitt', u'Edward Norton', u'Helena Bonham Carter']",
#  "[u'Elijah Wood', u'Ian McKellen', u'Orlando Bloom']",
#  "[u'Leonardo DiCaprio', u'Joseph Gordon-Levitt', u'Ellen Page']",
#  "[u'Mark Hamill', u'Harrison Ford', u'Carrie Fisher']",
#  "[u'Tom Hanks', u'Robin Wright', u'Gary Sinise']",
#  "[u'Elijah Wood', u'Ian McKellen', u'Viggo Mortensen']",
#  "[u'Matthew McConaughey', u'Anne Hathaway', u'Jessica Chastain']",
# ...

# %%
print(df['actors_list'].to_dict()[0])
# Out:
# [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']

# %%
df.value_counts()>50
# Out:
# star_rating  title                     content_rating  genre      duration  actors_list
# 7.4          A Bridge Too Far          PG              Drama      175       [u'Sean Connery', u"Ryan O'Neal", u'Michael Caine']                    False
# 8.0          Nosferatu                 UNRATED         Horror     81        [u'Max Schreck', u'Greta Schr\xf6der', u'Ruth Landshoff']              False
#              Persepolis                PG-13           Animation  96        [u'Chiara Mastroianni', u'Catherine Deneuve', u'Gena Rowlands']        False
#              Pink Floyd The Wall       R               Animation  95        [u'Bob Geldof', u'Christine Hargreaves', u'James Laurenson']           False
#              Planet of the Apes        G               Adventure  112       [u'Charlton Heston', u'Roddy McDowall', u'Kim Hunter']                 False
# ...

# %%
df[(df['title']=='R')|(df['title']=='God')]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
z=list(filter(lambda x: 'God'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 z=list(filter(lambda x: 'God'))
#
# TypeError: filter expected 2 arguments, got 1

# %%
# hw find "God" word from title column

# %%
# find if 'is' substring is present
result = sr.str.contains(pat = 'God')

# %%
result
# Out:
# 0    False
# dtype: bool
