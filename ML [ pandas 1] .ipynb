# %% [markdown]
# # Different type to create pandas dataframe

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
df = pd.read_csv('movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
#df1 = pd.read_csv('Bengaluru_House_Data.csv')
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
#using xlsx

# %%
df3 = pd.read_excel(r"C:\Users\jangi\Downloads\demo.xlsx")
df3
# Out:
#    id     name   city
# 0   0     ndss  t1fsd
# 1   1  ;smdvns   fsdm
# 2   2   fsvsjn     kd
# 3   3   kffksn     md
# 4   4     mksd     dm
# 5   5     ksdk    mkd
# 6   6   ksdkvs     kd
# 7   7   vsdmks   mksd
# 8   8       lk   leti

# %%
# create df from dictionary * all dict values must be same length {rows count}

# %%
py_dict = {
    'name':['copper','silver','iron','alumina'],
    'seg': ['a','s','a','t'],
    'price' : [588,959959,49949,994]
}

# %%
py_dict
# Out:
# {'name': ['copper', 'silver', 'iron', 'alumina'],
#  'seg': ['a', 's', 'a', 't'],
#  'price': [588, 959959, 49949, 994]}

# %%
df4 = pd.DataFrame(py_dict)
df4
# Out:
#       name seg   price
# 0   copper   a     588
# 1   silver   s  959959
# 2     iron   a   49949
# 3  alumina   t     994

# %%
# create df from list of dict

# %%
py = [
    {'id':101,'sales':123343,'temp':988439},
    {'id':102,'sales':343,'temp':91139},
    {'id':103,'sales':13,'temp':95555439},
]

# %%
df5 = pd.DataFrame(py)
df5
# Out:
#     id   sales      temp
# 0  101  123343    988439
# 1  102     343     91139
# 2  103      13  95555439

# %%
# create df from api

# %%
df6 = pd.read_json('https://api.sampleapis.com/beers/ale')

# %%
df6['image']
# Out:
# 0      https://www.totalwine.com/media/sys_master/twm...
# 1      https://www.totalwine.com/media/sys_master/twm...
# 2      https://www.totalwine.com/media/sys_master/twm...
# 3      https://www.totalwine.com/media/sys_master/twm...
# 4      https://www.totalwine.com/media/sys_master/twm...
#                              ...
# 184    https://www.totalwine.com/media/sys_master/twm...
# 185    https://www.totalwine.com/media/sys_master/twm...
# 186    https://www.totalwine.com/media/sys_master/twm...
# 187    https://www.totalwine.com/media/sys_master/twm...
# 188    https://www.totalwine.com/media/sys_master/twm...
# Name: image, Length: 189, dtype: object

# %%
df7 = pd.read_json('https://reqres.in/api/users?page=2')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df7 = pd.read_json('https://reqres.in/api/users?page=2')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import requests

# %%
r = requests.get('https://reqres.in/api/users?page=2')

# %%
r.content
# Out:
# b'{"page":2,"per_page":6,"total":12,"total_pages":2,"data":[{"id":7,"email":"michael.lawson@reqres.in","first_name":"Michael","last_name":"Lawson","avatar":"https://reqres.in/img/faces/7-image.jpg"},{"id":8,"email":"lindsay.ferguson@reqres.in","first_name":"Lindsay","last_name":"Ferguson","avatar":"https://reqres.in/img/faces/8-image.jpg"},{"id":9,"email":"tobias.funke@reqres.in","first_name":"Tobias","last_name":"Funke","avatar":"https://reqres.in/img/faces/9-image.jpg"},{"id":10,"email":"byron.fields@reqres.in","first_name":"Byron","last_name":"Fields","avatar":"https://reqres.in/img/faces/10-image.jpg"},{"id":11,"email":"george.edwards@reqres.in","first_name":"George","last_name":"Edwards","avatar":"https://reqres.in/img/faces/11-image.jpg"},{"id":12,"email":"rachel.howell@reqres.in","first_name":"Rachel","last_name":"Howell","avatar":"https://reqres.in/img/faces/12-image.jpg"}],"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions toward
# ...

# %%
import json

# %%
fp = open('temp.json','w')

pd.DataFrame(json.loads(r.content)['data'])
# Out:
#    id                       email first_name last_name  \
# 0   7    michael.lawson@reqres.in    Michael    Lawson
# 1   8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 2   9      tobias.funke@reqres.in     Tobias     Funke
# 3  10      byron.fields@reqres.in      Byron    Fields
# 4  11    george.edwards@reqres.in     George   Edwards
# 5  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1   https://reqres.in/img/faces/8-image.jpg
# 2   https://reqres.in/img/faces/9-image.jpg
# 3  https://reqres.in/img/faces/10-image.jpg
# 4  https://reqres.in/img/faces/11-image.jpg
# 5  https://reqres.in/img/faces/12-image.jpg

# %%
import requests
import bs4

response = requests.get("https://reqres.in/api/users?page=2")
soup = bs4.BeautifulSoup(response.content, "html.parser")
print(soup.prettify())
# Out:
# {"page":2,"per_page":6,"total":12,"total_pages":2,"data":[{"id":7,"email":"michael.lawson@reqres.in","first_name":"Michael","last_name":"Lawson","avatar":"https://reqres.in/img/faces/7-image.jpg"},{"id":8,"email":"lindsay.ferguson@reqres.in","first_name":"Lindsay","last_name":"Ferguson","avatar":"https://reqres.in/img/faces/8-image.jpg"},{"id":9,"email":"tobias.funke@reqres.in","first_name":"Tobias","last_name":"Funke","avatar":"https://reqres.in/img/faces/9-image.jpg"},{"id":10,"email":"byron.fields@reqres.in","first_name":"Byron","last_name":"Fields","avatar":"https://reqres.in/img/faces/10-image.jpg"},{"id":11,"email":"george.edwards@reqres.in","first_name":"George","last_name":"Edwards","avatar":"https://reqres.in/img/faces/11-image.jpg"},{"id":12,"email":"rachel.howell@reqres.in","first_name":"Rachel","last_name":"Howell","avatar":"https://reqres.in/img/faces/12-image.jpg"}],"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards 
# ...

# %%
import requests
import bs4

response = requests.get("https://www.bankbazaar.com/reviews.html")
soup = bs4.BeautifulSoup(response.content, "html.parser")
print(soup.find_all('div')[15:])
# Out:
# [<div class="child-main-menu" data-actionloc=":hamBurgerMenu">
# <a data-action="click:menuClick:inclData" data-name="productType" data-product="income-tax" data-target="#tax-tab" href="/income-tax.html" title="Income Tax">
#                                             Income Tax</a>
# <a data-action="click:menuClick:inclData" data-name="productType" data-product="ifsc-code" data-target="#bank-ifsc-tab" href="/ifsc-code.html" title="Bank IFSC Codes">
#                                             Bank IFSC Codes</a>
# <a data-action="click:menuClick:inclData" data-name="productType" data-product="indian-holiday" data-target="#indian-holiday-tab" href="/indian-holiday-calendar.html" title="Indian Holidays List">
#                                             Indian Holidays List</a>
# <a data-action="click:menuClick:inclData" data-name="productType" data-product="reviews" data-target="#rating-review-tab" href="/reviews.html" title="Ratings &amp; Reviews">
# ...

# %%
import pandas as pd

data1 = pd.read_html('https://www.bankbazaar.com/reviews.html,skiprows=1)[0]
# Out:
#   Input In [60]
#     data1 = pd.read_html('https://www.bankbazaar.com/reviews.html,skiprows=1)[0]
#                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
# !pip install html5lib

# %%
df8 = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory')

# %%
df8[12]
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                               Bosnia and Herzegovina
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df1[['area_type','location','total_sqft','society']]
# Out:
#                   area_type                  location total_sqft  society
# 0      Super built-up  Area  Electronic City Phase II       1056  Coomee
# 1                Plot  Area          Chikka Tirupathi       2600  Theanmp
# 2            Built-up  Area               Uttarahalli       1440      NaN
# 3      Super built-up  Area        Lingadheeranahalli       1521  Soiewre
# 4      Super built-up  Area                  Kothanur       1200      NaN
# ...                     ...                       ...        ...      ...
# 13315        Built-up  Area                Whitefield       3453  ArsiaEx
# 13316  Super built-up  Area             Richards Town       3600      NaN
# 13317        Built-up  Area     Raja Rajeshwari Nagar       1141  Mahla T
# 13318  Super built-up  Area           Padmanabhanagar       4689  SollyCl
# 13319  Super built-up  Area              Doddathoguru        550      NaN
#
# [13320 rows x 4 columns]

# %%
df1[['availability','price','size']]
# Out:
#         availability   price       size
# 0             19-Dec   39.07      2 BHK
# 1      Ready To Move  120.00  4 Bedroom
# 2      Ready To Move   62.00      3 BHK
# 3      Ready To Move   95.00      3 BHK
# 4      Ready To Move   51.00      2 BHK
# ...              ...     ...        ...
# 13315  Ready To Move  231.00  5 Bedroom
# 13316  Ready To Move  400.00      4 BHK
# 13317  Ready To Move   60.00      2 BHK
# 13318         18-Jun  488.00      4 BHK
# 13319  Ready To Move   17.00      1 BHK
#
# [13320 rows x 3 columns]

# %%
# list compresion

# %%
col_list = [col for col in df.columns if col.startswith('a')]

# %%
col_list
# Out:
# ['area_type', 'availability']

# %%
 df['size']
# Out:
# 0            2 BHK
# 1        4 Bedroom
# 2            3 BHK
# 3            3 BHK
# 4            2 BHK
#            ...
# 13315    5 Bedroom
# 13316        4 BHK
# 13317        2 BHK
# 13318        4 BHK
# 13319        1 BHK
# Name: size, Length: 13320, dtype: object

# %% [markdown]
# ## select multiple columns

# %%
 df[['size','area_type']]
# Out:
#             size             area_type
# 0          2 BHK  Super built-up  Area
# 1      4 Bedroom            Plot  Area
# 2          3 BHK        Built-up  Area
# 3          3 BHK  Super built-up  Area
# 4          2 BHK  Super built-up  Area
# ...          ...                   ...
# 13315  5 Bedroom        Built-up  Area
# 13316      4 BHK  Super built-up  Area
# 13317      2 BHK        Built-up  Area
# 13318      4 BHK  Super built-up  Area
# 13319      1 BHK  Super built-up  Area
#
# [13320 rows x 2 columns]

# %%
df.area_type
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
# .(dot) df.column name is not applicable in case when space between column name
 # that time we will use df['colname']

# %% [markdown]
# # multiple columns access

# %%
df[col_list]
# Out:
#                   area_type   availability
# 0      Super built-up  Area         19-Dec
# 1                Plot  Area  Ready To Move
# 2            Built-up  Area  Ready To Move
# 3      Super built-up  Area  Ready To Move
# 4      Super built-up  Area  Ready To Move
# ...                     ...            ...
# 13315        Built-up  Area  Ready To Move
# 13316  Super built-up  Area  Ready To Move
# 13317        Built-up  Area  Ready To Move
# 13318  Super built-up  Area         18-Jun
# 13319  Super built-up  Area  Ready To Move
#
# [13320 rows x 2 columns]

# %%
# kuch colname chor ke * use 'not'

# %%
col_list = [col for col in df.columns if not col.startswith('a')]

# %%
col_list
# Out:
# ['location', 'size', 'society', 'total_sqft', 'bath', 'balcony', 'price']

# %%
col_list
# Out:
# ['location', 'size', 'society', 'total_sqft', 'bath', 'balcony', 'price']

# %%
df[col_list]
# Out:
#                        location       size  society total_sqft  bath  balcony  \
# 0      Electronic City Phase II      2 BHK  Coomee        1056   2.0      1.0
# 1              Chikka Tirupathi  4 Bedroom  Theanmp       2600   5.0      3.0
# 2                   Uttarahalli      3 BHK      NaN       1440   2.0      3.0
# 3            Lingadheeranahalli      3 BHK  Soiewre       1521   3.0      1.0
# 4                      Kothanur      2 BHK      NaN       1200   2.0      1.0
# ...                         ...        ...      ...        ...   ...      ...
# 13315                Whitefield  5 Bedroom  ArsiaEx       3453   4.0      0.0
# 13316             Richards Town      4 BHK      NaN       3600   5.0      NaN
# 13317     Raja Rajeshwari Nagar      2 BHK  Mahla T       1141   2.0      1.0
# 13318           Padmanabhanagar      4 BHK  SollyCl       4689   4.0      1.0
# 13319              Doddathoguru      1 BHK      NaN        550   1.0      1.0
#
#         price
# 0       39.07
# ...

# %%
# Check columndata datatype

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %% [markdown]
# # Short analysis----stats analysis

# %%
 df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %% [markdown]
# # col analysis

# %%
df1.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df1['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)
