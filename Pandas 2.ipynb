# %%
import pandas as pd

# %%
df22 = pd.read_csv('movies.csv')
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
# !pip install html5lib

# %%
df22.shape
# Out:
# (27278, 3)

# %%
df22.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
 len(df22['genres'].unique())
# Out:
# 1342

# %%
df22['genres'].value_counts()
# Out:
# Drama                                                  4520
# Comedy                                                 2294
# Documentary                                            1942
# Comedy|Drama                                           1264
# Drama|Romance                                          1075
#                                                        ...
# Action|Comedy|Crime|Western                               1
# Action|Fantasy|Sci-Fi|Thriller                            1
# Action|Drama|Fantasy|Horror|Mystery|Sci-Fi|Thriller       1
# Action|Drama|Fantasy|Romance                              1
# Animation|Children|Comedy|Western                         1
# Name: genres, Length: 1342, dtype: int64

# %% [markdown]
# # DataFrame is a tool to analysis data and it is use in ML
# # dataframe is a mutable type

# %% [markdown]
# # New column addition

# %%
df22['test'] = 100

# %%
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
df22['title_genres']= df22['title']+df22['genres']
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
df22['new_movieid']= (df22['movieId']/100)*5
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
df22['title_len']=len(df22['title'])
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
def sqr(r):
    return len(r)

# %%
df22['new_genres']=df22['genres'].map(sqr)
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
len('Adventure|Fantasy|Horror')
# Out:
# 24

# %%
df22['new_genres'].value_counts()
# Out:
# 5     4572
# 6     3159
# 11    2402
# 13    2097
# 12    1900
# 14    1817
# 20    1358
# 15    1051
# 21     971
# 22     832
# 18     749
# 23     592
# 9      576
# 16     571
# 19     481
# 7      408
# 28     360
# 24     349
# 17     332
# 8      292
# 29     275
# 25     257
# 26     252
# 27     239
# 30     208
# 31     183
# 32     121
# 35     110
# 36      95
# 33      87
# 34      77
# 10      63
# 37      61
# 38      55
# 39      47
# 40      43
# 43      35
# 41      33
# 42      33
# 3       32
# 44      15
# 47      15
# 50      13
# 51      10
# 48       8
# 45       7
# 49       7
# 46       6
# 54       5
# 52       4
# 60       3
# 57       2
# 55       2
# 59       1
# 56       1
# 4        1
# 62       1
# 65       1
# 77       1
# Name: new_genres, dtype: int64

# %%
df22['genres'].value_counts()
# Out:
# Drama                                                  4520
# Comedy                                                 2294
# Documentary                                            1942
# Comedy|Drama                                           1264
# Drama|Romance                                          1075
#                                                        ...
# Action|Comedy|Crime|Western                               1
# Action|Fantasy|Sci-Fi|Thriller                            1
# Action|Drama|Fantasy|Horror|Mystery|Sci-Fi|Thriller       1
# Action|Drama|Fantasy|Romance                              1
# Animation|Children|Comedy|Western                         1
# Name: genres, Length: 1342, dtype: int64

# %%
[f for f in df22['genres'] if len(f)==5]
# Out:
# ['Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
# ...

# %%
len([f for f in df22['genres'] if len(f)==5])
# Out:
# 4572

# %%
# find col_value count @ individual level

# %%
df22 ['new_t1_genres']= df22['genres'].map(lambda x:len(x))
df22
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  test  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   100
# 1                       Adventure|Children|Fantasy   100
# 2                                   Comedy|Romance   100
# 3                             Comedy|Drama|Romance   100
# 4                                           Comedy   100
# ...

# %%
# first few rows  -------> df.head()

# %%
df22.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  test  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   100
# 1                   Adventure|Children|Fantasy   100
# 2                               Comedy|Romance   100
# 3                         Comedy|Drama|Romance   100
# 4                                       Comedy   100
#
#                                         title_genres  new_movieid  title_len  \
# 0  Toy Story (1995)Adventure|Animation|Children|C...         0.05      27278
# 1           Jumanji (1995)Adventure|Children|Fantasy         0.10      27278
# 2              Grumpier Old Men (1995)Comedy|Romance         0.15      27278
# ...

# %%
df22.tail()
# Out:
#        movieId                          title                    genres  test  \
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy   100
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy   100
# 27275   131258             The Pirates (2014)                 Adventure   100
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)   100
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror   100
#
#                                    title_genres  new_movieid  title_len  \
# 27273        Kein Bund für's Leben (2007)Comedy       6562.7      27278
# 27274       Feuer, Eis & Dosenbier (2002)Comedy       6562.8      27278
# 27275               The Pirates (2014)Adventure       6562.9      27278
# 27276     Rentun Ruusu (2001)(no genres listed)       6563.0      27278
# 27277  Innocence (2014)Adventure|Fantasy|Horror       6563.1      27278
#
#        new_genres  new_t1_genres
# ...

# %%
 df22.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres  test  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   100
# 1                   Adventure|Children|Fantasy   100
# 2                               Comedy|Romance   100
# 3                         Comedy|Drama|Romance   100
# 4                                       Comedy   100
# 5                        Action|Crime|Thriller   100
# 6                               Comedy|Romance   100
# ...

# %%
df22.isnull().sum()
# Out:
# movieId          0
# title            0
# genres           0
# test             0
# title_genres     0
# new_movieid      0
# title_len        0
# new_genres       0
# new_t1_genres    0
# dtype: int64

# %%
df22.notnull().sum()
# Out:
# movieId          27278
# title            27278
# genres           27278
# test             27278
# title_genres     27278
# new_movieid      27278
# title_len        27278
# new_genres       27278
# new_t1_genres    27278
# dtype: int64

# %%
type(df22['test'])
# Out:
# pandas.core.series.Series

# %%
df22['genres']= df22['genres'].map(lambda x:str(x)[:1])

# %%
df22
# Out:
#        movieId                               title genres  test  \
# 0            1                    Toy Story (1995)      A   100
# 1            2                      Jumanji (1995)      A   100
# 2            3             Grumpier Old Men (1995)      C   100
# 3            4            Waiting to Exhale (1995)      C   100
# 4            5  Father of the Bride Part II (1995)      C   100
# ...        ...                                 ...    ...   ...
# 27273   131254        Kein Bund für's Leben (2007)      C   100
# 27274   131256       Feuer, Eis & Dosenbier (2002)      C   100
# 27275   131258                  The Pirates (2014)      A   100
# 27276   131260                 Rentun Ruusu (2001)      (   100
# 27277   131262                    Innocence (2014)      A   100
#
#                                             title_genres  new_movieid  \
# 0      Toy Story (1995)Adventure|Animation|Children|C...         0.05
# ...

# %% [markdown]
# # filling null values

# %%
 df22.fillna(0,inplace=True)
df22
# Out:
#        movieId                               title genres  test  \
# 0            1                    Toy Story (1995)      A   100
# 1            2                      Jumanji (1995)      A   100
# 2            3             Grumpier Old Men (1995)      C   100
# 3            4            Waiting to Exhale (1995)      C   100
# 4            5  Father of the Bride Part II (1995)      C   100
# ...        ...                                 ...    ...   ...
# 27273   131254        Kein Bund für's Leben (2007)      C   100
# 27274   131256       Feuer, Eis & Dosenbier (2002)      C   100
# 27275   131258                  The Pirates (2014)      A   100
# 27276   131260                 Rentun Ruusu (2001)      (   100
# 27277   131262                    Innocence (2014)      A   100
#
#                                             title_genres  new_movieid  \
# 0      Toy Story (1995)Adventure|Animation|Children|C...         0.05
# ...

# %%
df22.isnull().sum().to_dict()
# Out:
# {'movieId': 0,
#  'title': 0,
#  'genres': 0,
#  'test': 0,
#  'title_genres': 0,
#  'new_movieid': 0,
#  'title_len': 0,
#  'new_genres': 0,
#  'new_t1_genres': 0}

# %%
# to store null values as your required place in particular col

# %%
df22['genres'] = df22['genres'].fillna(10)
df22 # HERE NO NULL THATS why in table thier is no change appear
# Out:
#        movieId                               title genres  test  \
# 0            1                    Toy Story (1995)      A   100
# 1            2                      Jumanji (1995)      A   100
# 2            3             Grumpier Old Men (1995)      C   100
# 3            4            Waiting to Exhale (1995)      C   100
# 4            5  Father of the Bride Part II (1995)      C   100
# ...        ...                                 ...    ...   ...
# 27273   131254        Kein Bund für's Leben (2007)      C   100
# 27274   131256       Feuer, Eis & Dosenbier (2002)      C   100
# 27275   131258                  The Pirates (2014)      A   100
# 27276   131260                 Rentun Ruusu (2001)      (   100
# 27277   131262                    Innocence (2014)      A   100
#
#                                             title_genres  new_movieid  \
# 0      Toy Story (1995)Adventure|Animation|Children|C...         0.05
# ...

# %%
df22.fillna(100)
# Out:
#        movieId                               title genres  test  \
# 0            1                    Toy Story (1995)      A   100
# 1            2                      Jumanji (1995)      A   100
# 2            3             Grumpier Old Men (1995)      C   100
# 3            4            Waiting to Exhale (1995)      C   100
# 4            5  Father of the Bride Part II (1995)      C   100
# ...        ...                                 ...    ...   ...
# 27273   131254        Kein Bund für's Leben (2007)      C   100
# 27274   131256       Feuer, Eis & Dosenbier (2002)      C   100
# 27275   131258                  The Pirates (2014)      A   100
# 27276   131260                 Rentun Ruusu (2001)      (   100
# 27277   131262                    Innocence (2014)      A   100
#
#                                             title_genres  new_movieid  \
# 0      Toy Story (1995)Adventure|Animation|Children|C...         0.05
# ...
